# %%
import requests
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
naver = requests.get("https://api.github.com/orgs/naver/repos").json()
naver
# Out:
# [{'id': 4709330,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0NzA5MzMw',
#   'name': 'ngrinder',
#   'full_name': 'naver/ngrinder',
#   'private': False,
#   'owner': {'login': 'naver',
#    'id': 6589568,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY1ODk1Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6589568?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/naver',
#    'html_url': 'https://github.com/naver',
#    'followers_url': 'https://api.github.com/users/naver/followers',
#    'following_url': 'https://api.github.com/users/naver/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/naver/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/naver/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/naver/subscriptions',
#    'organizations_url': 'https://api.github.com/users/naver/orgs',
#    'repos_url': 'https://api.github.com/users/naver/repos',
# ...

# %%
language = {}
headers = {
    "Authorization": "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"
}

for element in naver:
    naver_language = requests.get(element["languages_url"], headers=headers).json()
    for k, v in naver_language.items():
        if k in language.keys():
            language[k] += v
        else:
            language[k] = v

# %%
language
# Out:
# {'Java': 14075669,
#  'Vue': 441312,
#  'JavaScript': 25557257,
#  'FreeMarker': 9845,
#  'Groovy': 28251,
#  'Python': 335938,
#  'CSS': 1279236,
#  'HTML': 188092965,
#  'Shell': 189829,
#  'Dockerfile': 2911,
#  'Batchfile': 8077,
#  'Scala': 25333,
#  'PLSQL': 11068,
#  'PLpgSQL': 545,
#  'SQLPL': 131,
#  'C': 3769684,
#  'Perl': 816441,
#  'M4': 308530,
#  'Makefile': 34294,
#  'DTrace': 11527,
#  'Starlark': 1640,
#  'C++': 3023763,
#  'XS': 66352,
#  'Raku': 40860,
#  'Mako': 13678,
#  'CMake': 6863,
#  'XSLT': 6024,
#  'Ruby': 67964,
#  'Lua': 2729,
#  'GDB': 37,
#  'ActionScript': 14083,
#  'PHP': 3690,
#  'Groff': 160}

# %%
kakao_language = {}
kakao = requests.get("https://api.github.com/orgs/kakao/repos", headers=headers).json()

# %%
kakao
# Out:
# {'message': "API rate limit exceeded for 218.39.184.157. (But here's the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)",
#  'documentation_url': 'https://docs.github.com/rest/overview/resources-in-the-rest-api#rate-limiting'}

# %%
for i in kakao:
    print(i)
# Out:
# message
# documentation_url

# %%
for element in kakao:
    lang = requests.get(element["languages_url"], headers=headers).json()
    for k, v in lang.items():
        if k in kakao_language.keys():
            kakao_language[k] += v
        else:
            kakao_language[k] = v
            
kakao_language
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/y1/2m7yw7zj0vvcl76pdwhpqf5m0000gn/T/ipykernel_28180/3012040513.py in <module>
#       3
#       4 for element in kakao:
# ----> 5     lang = requests.get(element["languages_url"], headers=headers).json()
#       6     for k, v in lang.items():
#       7         if k in kakao_language.keys():
#
# TypeError: string indices must be integers

# %%
corporate = pd.read_csv("./corporate.csv", encoding='CP949')
corporate.head()
# Out:
#    기업일련번호   업체국문명 업체영문명 기업한줄소개내용 기업소개상세내용  설립일자 구성원수  누적투자유치금액 홈페이지url  \
# 0  161069    코뿔소랩   NaN      NaN      NaN   NaN  NaN       NaN     NaN
# 1  116057   현대제이콤   NaN      NaN      NaN   NaN  NaN       NaN     NaN
# 2  161065  지티투자개발   NaN      NaN      NaN   NaN  NaN       NaN     NaN
# 3  161066   동성아트홀   NaN      NaN      NaN   NaN  NaN       NaN     NaN
# 4  161072    오픈부스   NaN      NaN      NaN   NaN  NaN       NaN     NaN
#
#   소셜미디어url  기업추천수 기업추천내용 산업구분명 사무실주소 기술스택명 발행사명  보도일자 뉴스제목명 기사url
# 0      NaN      0    NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN
# 1      NaN      0    NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN
# 2      NaN      0    NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN
# 3      NaN      0    NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN
# 4      NaN      0    NaN   NaN   NaN   NaN  NaN   NaN   NaN   NaN
